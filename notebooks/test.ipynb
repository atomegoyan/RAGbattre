# %%
import os

# %%
os.getcwd()
# Out:
# '/home/atom/Bureau/Aurelien/RAGbattre'

# %%
import os
import json
import regex as re
import chromadb
import sys
import ast
from chromadb.utils import embedding_functions
sys.path.append(os.getcwd())
from retrieval_app.core import EMBEDDINGS_DIR , MAX_CHAR_DISPLAY
from retrieval_app.core import EMBEDDING_DEVICE , RERANKING_DEVICE
from retrieval_app.core import DEFAULT_EMBEDDING_MODEL , CORPUS_DIR
# Out:
# /home/atom/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
client = chromadb.PersistentClient(path=EMBEDDINGS_DIR)
collection_name = client.list_collections()

# %%
collection_name
# Out:
# ['1881-01-20']

# %%
from retrieval_app.core import initialize_chromadb

# %%
client , collection , ef = initialize_chromadb(collection_name[0],DEFAULT_EMBEDDING_MODEL)

# %%
collection.get(include=["documents"])
# Out:
# {'ids': ['1881-01-20_000.txt',
#   '1881-01-20_001.txt',
#   '1881-01-20_002.txt',
#   '1881-01-20_003.txt',
#   '1881-01-20_004.txt',
#   '1881-01-20_005.txt',
#   '1881-01-20_006.txt',
#   '1881-01-20_007.txt',
#   '1881-01-20_008.txt',
#   '1881-01-20_009.txt'],
#  'embeddings': None,
#  'documents': ['.',
#   'CHAMBRE DES DÉPUTÉS Session ordinaire de 1881',
# ...

# %%
def query_seance(seance,corpus_path) :
    with open(os.path.join(corpus_path,seance+".txt")) as f : 
        text = f.read()
        return text[:MAX_CHAR_DISPLAY]

# %%
text = query_seance(collection_name,CORPUS_DIR)

# %%
from retrieval_app.ollama_utils import get_ollama_response_mistral
messages = [
        {
            "role": "user",
            "content": "What is the best French cheese?",
        },
    ]
#resp = get_ollama_response_mistral(messages=messages)

# %%
resp = get_ollama_response_mistral("aa",messages=messages,system="Tu m'aide")

# %%
print(resp)
# Out:
# Choosing the "best" French cheese can be subjective and depends on personal preferences, as France offers a wide variety of exceptional cheeses. Here are a few that are often highly regarded:
#
# 1. **Camembert de Normandie**: A soft, creamy cheese from the Normandy region, known for its rich, buttery flavor.
# 2. **Brie de Meaux**: Often referred to as the "King of Cheeses," this soft cheese from the Île-de-France region is famous for its creamy texture and slightly nutty taste.
# 3. **Roquefort**: A blue cheese made from sheep's milk, known for its strong, tangy flavor and distinctive blue veins.
# 4. **Comté**: A hard, unpasteurized cow's milk cheese from the Jura region, with a complex, nutty flavor that varies depending on its aging.
# 5. **Reblochon**: A soft washed-rind and smear-ripened cheese from the Alps, known for its creamy texture and nutty taste.
# 6. **Époisses**: A pungent, washed-rind cheese from Burgundy, known for its strong aroma and rich, salty flavor.
# ...
